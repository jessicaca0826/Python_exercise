# %% [markdown]
# <a href="https://colab.research.google.com/github/jessicaca0826/Python_exercise/blob/main/%E6%96%B0%E8%81%9E%E8%AA%9E%E6%96%99%E9%97%9C%E9%8D%B5%E5%AD%97%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
# 利用 requests 對 API 來源發送一個請求
url='https://udn.com/news/breaknews/1'
response=requests.get(url)
soup=BeautifulSoup(response.text)
news=[]
for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
  news_url=link.a['href']
  news_response=requests.get('http://udn.com'+news_url)
  news_soup=BeautifulSoup(news_response.text)
  news_content=news_soup.find('div',class_='article-content__paragraph').text.strip().replace('\n',' ')
  news.append(news_content)
print(news)
# Out:
# ['民眾黨立法院黨團總召黃國昌昨天說，民進黨大老吳乃仁賤賣台糖土地，服完刑後未償還造成國家損失，除乘坐高級豪車與政商權貴聚會，去年底還現身高檔無菜單料理餐廳，席間竟有北檢檢察官徐名駒；知情人士透露，該餐廳是米其林名店「AD ASTRA」，隱蔽性相當高，老闆是來自紐約的星級主廚，想預約相當困難，且當天共有5名檢察官在場。 \r 消息指出，當天餐會是徐名駒主揪，時間是2024年12月26日，有4名北部檢察官受邀，邀約名義是「歲末年終聚會」，4名檢座原以為是老同學聚餐，沒想到現場還有「柏君人力資源管理顧問公司」負責人陳啟莊，吳乃仁則是用餐後不久現身，這4人對吳乃仁會出席應不知情，感覺是有心人設局「請君入甕」。            \r 「AD ASTRA」是由米其林二星主廚凱文·羅斯（Kevin Rose）開設，曾管理紐約一流星級廚房，此餐廳從品牌識別、空間到菜單，全由Kevin 一手包辦，以台灣食材打造新料理，開幕以來吸引政商饕客到訪，想訂位相當困難，身為檢察官的徐名駒能訂此餐廳，想必人脈豐沛。 \r 黃國昌指控，去年底吳乃仁現身在高檔無菜單料理餐廳，從事人力仲介的陳董負責招呼接待，席間竟還有台北地檢署檢察官徐名駒一行人。他請問曾任廉政署長的法務部長鄭銘謙，徐名駒等人是否有逾越檢察官倫理守則？該場餐敘由誰牽線？6萬元的包廂由誰埋單？北檢昨晚回應，「將啟動行政調查」。 \r 據了解，徐名駒早年在士林地檢署服務，後來因有爭議調往北檢公訴組，檢察總長邢泰釗擔任北檢檢察長期間，要求他要回到偵查組辦案，不要占公訴缺，徐名駒後來一度調往緝毒組，期間還發紅帖娶嬌妻，後來大休一年，平常辦案表現平平。 \r 黃國昌指出，台糖以吳乃仁名下查無財產替其遮掩，台北地方法院執行處也不敢認真踐行強制執行程序，造成全體納稅人的損失，綠營權貴橫著走，公平正義蕩然無存，其本身的政治影響力，連檢察官都得敬他三分。民進黨大老吳乃仁現身米其林一星名店「AD ASTRA」。記者張宏業／攝影米其林一星名店「AD ASTRA」裝潢典雅，走奢華低調風。圖／翻攝     吳乃仁 檢察官 米其林 餐廳 黃國昌', '朝野對抗激烈，民進黨團總召柯建銘喊出「雙罷」，身兼民進黨主席的賴清德總統昨說，有其他的憲政程序可以努力，外界解讀「踩煞車」。台灣民意基金會董事長游盈隆在臉書表示，欣見台灣避開一場荒謬絕倫的大罷免鬧劇。 
# ...

# %%
# 安裝 jieba 中文斷詞套件
# !pip install jieba

# 下載官方字典檔
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Out:
# ...
# --2025-01-09 14:05:27--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [application/octet-stream]
# Saving to: ‘dict.txt.big’
#
# dict.txt.big        100%[===================>]   8.18M  --.-KB/s    in 0.07s
#
# 2025-01-09 14:05:28 (118 MB/s) - ‘dict.txt.big’ saved [8583143/8583143]

# %%
# 載入套件與字典檔
import jieba
jieba.load_userdict('dict.txt.big')

# 精確模式斷詞
tokens=[]
for d in news:
  token=jieba.cut(d)
  tokens.extend(token)
print(tokens)

word_count={}
for d in tokens:
  if d not in word_count:
    word_count[d]=1
  else:
    word_count[d]+=1
print(word_count)
# Out:
# ['民眾', '黨', '立法院', '黨團', '總召', '黃國', '昌', '昨天', '說', '，', '民進黨', '大老', '吳乃仁', '賤賣', '台糖', '土地', '，', '服完', '刑後未', '償還', '造成', '國家', '損失', '，', '除', '乘坐', '高級', '豪車', '與', '政商', '權貴', '聚會', '，', '去年底', '還', '現身', '高檔', '無', '菜單', '料理', '餐廳', '，', '席間', '竟有', '北檢', '檢察官', '徐', '名駒', '；', '知情', '人士', '透露', '，', '該', '餐廳', '是', '米其林', '名店', '「', 'AD', ' ', 'ASTRA', '」', '，', '隱蔽性', '相當', '高', '，', '老闆', '是', '來自', '紐約', '的', '星級', '主廚', '，', '想', '預約', '相當', '困難', '，', '且', '當天', '共有', '5', '名', '檢察官', '在場', '。', ' ', '\r', ' ', '消息', '指出', '，', '當天', '餐會', '是', '徐', '名駒', '主', '揪', '，', '時間', '是', '2024', '年', '12', '月', '26', '日', '，', '有', '4', '名', '北部', '檢察官', '受邀', '，', '邀約', '名義', '是', '「', '歲末', '年終', '聚會', '」', '，', '4', '名檢座', '原以', '為', '是', '老同學', '聚餐', '，', '沒想到', '現場', '還有', '「', '柏君', '人力', '資源管理', '顧問公司', '」', '負責人', '陳', '啟莊', '，', '吳乃仁則', '是', '用餐', '後', '不久', '現身', '，', '這', '4', '人', '對', '吳乃仁會', '出席', '應', '不知情', '，', '感覺', '是', '有心人', '設局', '「', '請君入甕', '」', '。', ' 
# ...
